# %% [markdown]
# <a href="https://colab.research.google.com/github/RayAKaan/scratch-ml-models/blob/main/Scratch_LR_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
class LinearRegression():
    def _init_(self):
      self.bias=None
      self.weight=None
      self.x_mean=None

    def fit(self,x,y):
      x_mean=x.mean()
      y_mean=y.mean()

      num=0
      den=0

      for i in range(len(x)):
        num+=(x[i]-x_mean)*(y[i]-y_mean)
        den+=(x[i]-x_mean)**2

      self.weight=num/den
      self.bias=y_mean-(self.weight*x_mean)

    def predict(self,x):
     return self.bias+(self.weight*x)

# %%
df = pd.read_csv('salary_data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x=df['YearsExperience']
y=df['Salary']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,)
model=LinearRegression()
model.fit(np.array(x_train),np.array(y_train))
y_pred=model.predict(np.array(x_test))

# %%
print(f'Weight:{model.weight}')
print(f'Bias:{model.bias}')
# Out:
# Weight:9556.468202383048
# Bias:25792.20283717735

# %%
plt.title('YearsofExperience vs Salary')
plt.xlabel('YearsofExperience')
plt.ylabel('Salary')
plt.scatter(x,y)
plt.plot(x,model.bias+model.weight*x,'r-')
plt.show()
